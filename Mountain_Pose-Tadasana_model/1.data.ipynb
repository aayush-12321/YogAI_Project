# %%
import mediapipe as mp
import cv2
import numpy as np
import pandas as pd
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# Drawing helpers
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %% [markdown]
# ### 1. Make some pose detections (Test if Everything works correctly)

# %%
cap = cv2.VideoCapture("sample7.mp4")

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, image = cap.read()
        image = cv2.flip(image, 1)

        if not ret:
            break

        # Recolor image from BGR to RGB for mediapipe
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = pose.process(image)

        # Recolor image from BGR to RGB for mediapipe
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw landmarks and connections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # frame_count = 0  #
        # if frame_count > 20:  # show only first 20 frames  #
        #     break  #
        
        cv2.namedWindow("CV2", cv2.WINDOW_NORMAL)
        cv2.resizeWindow("CV2", 900, 600)

        cv2.imshow("CV2", image)

        # Press Q to close cv2 window
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

    for i in range (1, 5):
        cv2.waitKey(1)

# %% [markdown]
# ### 2. Build dataset from collected videos and picture from Kaggle to .csv file for dataset

# %%
import csv
import os

# %% [markdown]
# #### 2.1 Determine important keypoints and set up important functions

# %% [markdown]
# - Correct: "C"

# %% [markdown]
# **Important Landmarks**
# - 0:   nose
# - 7:   left_ear
# - 8:   right_ear
# - 11:  left_shoulder
# - 12:  right_shoulder
# - 13:  left_elbow
# - 14:  right_elbow
# - 15:  left_wrist
# - 16:  right_wrist
# - 19:  left_index
# - 20:  right_index
# - 23:  left_hip
# - 24:  right_hip
# - 25:  left_knee
# - 26:  right-knee
# - 27:  left_ankle
# - 28:  right_ankle
# - 29:  left_heel
# - 30:  right_heel

# %%
# Determine important landmarks for plank
IMPORTANT_LMS = [
    "NOSE",             # 0
    "LEFT_EAR",         # 7
    "RIGHT_EAR",        # 8
    "LEFT_SHOULDER",    # 11
    "RIGHT_SHOULDER",   # 12
    "LEFT_ELBOW",       # 13
    "RIGHT_ELBOW",      # 14
    "LEFT_WRIST",       # 15
    "RIGHT_WRIST",      # 16
    "LEFT_INDEX",       # 19
    "RIGHT_INDEX",      # 20
    "LEFT_HIP",         # 23
    "RIGHT_HIP",        # 24
    "LEFT_KNEE",        # 25
    "RIGHT_KNEE",       # 26
    "LEFT_ANKLE",       # 27
    "RIGHT_ANKLE",      # 28
    "LEFT_HEEL",        # 29
    "RIGHT_HEEL"        # 30
]


# Generate all columns of the data frame

HEADERS = ["label"] # Label column

for lm in IMPORTANT_LMS:
    HEADERS += [f"{lm.lower()}_x", f"{lm.lower()}_y", f"{lm.lower()}_z", f"{lm.lower()}_v"]

# %%
def filter_important_landmarks(input_csv, important_landmarks=IMPORTANT_LMS):
# def filter_important_landmarks(input_csv, output_csv, important_landmarks=IMPORTANT_LMS):
    """
    Filter CSV to keep only important landmarks
    
    Args:
        input_csv: Path to full CSV with all 33 landmarks
        # output_csv: Path to save filtered CSV
        important_landmarks: List of landmark names (uppercase) to keep
    """
    print(f"📊 Filtering landmarks from {input_csv}...")
    
    # Read the full CSV
    df = pd.read_csv(input_csv)
    output_csv = f'main_{input_csv}'
    
    # Convert landmark names to lowercase for matching
    important_lms_lower = [lm.lower() for lm in important_landmarks]
    
    # Columns to keep: label + selected landmarks with x, y, z, visibility
    columns_to_keep = ['label']
    
    for landmark in important_lms_lower:
        columns_to_keep.extend([
            f'{landmark}_x',
            f'{landmark}_y',
            f'{landmark}_z',
            f'{landmark}_v'
        ])
    
    # Check if all columns exist
    missing_cols = [col for col in columns_to_keep if col not in df.columns]
    if missing_cols:
        print(f"⚠️  Warning: Missing columns: {missing_cols}")
        # Keep only existing columns
        columns_to_keep = [col for col in columns_to_keep if col in df.columns]
    
    # Filter the dataframe
    df_filtered = df[columns_to_keep]
    
    # Save to new CSV
    df_filtered.to_csv(output_csv, index=False)
    
    print(f"✅ Filtered CSV saved to {output_csv}")
    print(f"   Original: {len(df.columns)} columns → Filtered: {len(df_filtered.columns)} columns")
    print(f"   Kept {len(important_landmarks)} landmarks × 4 values + 1 label = {len(df_filtered.columns)} total")
    print(f"   Total rows: {len(df_filtered)}")
    
    return df_filtered


cv2.destroyAllWindows()
print("🏁 Data extraction completed!")
# Out:
# 🏁 Data extraction completed!

# %%
def combine_and_cleanup_csvs(csv1, csv2, delete_originals=True):
# def combine_and_cleanup_csvs(csv1, csv2, output_csv, delete_originals=True):
    """
    Combine two CSV files and optionally delete the originals
    
    Args:
        csv1: Path to first CSV file
        csv2: Path to second CSV file
        output_csv: Path to save combined CSV
        delete_originals: If True, delete the original CSV files after combining
    """
    print(f"🔗 Combining CSV files...")
    print(f"   📄 {csv1}")
    print(f"   📄 {csv2}")

    output_csv = 'train.csv'
    
    # Read both CSVs
    try:
        df1 = pd.read_csv(csv1)
        print(f"   ✓ Loaded {csv1}: {len(df1)} rows, {len(df1.columns)} columns")
    except FileNotFoundError:
        print(f"   ❌ File not found: {csv1}")
        return None
    
    try:
        df2 = pd.read_csv(csv2)
        print(f"   ✓ Loaded {csv2}: {len(df2)} rows, {len(df2.columns)} columns")
    except FileNotFoundError:
        print(f"   ❌ File not found: {csv2}")
        return None
    
    # Check if columns match
    if list(df1.columns) != list(df2.columns):
        print("   ⚠️  Warning: Column names don't match perfectly")
        print(f"      CSV1 columns: {len(df1.columns)}")
        print(f"      CSV2 columns: {len(df2.columns)}")
    
    # Combine the dataframes
    df_combined = pd.concat([df1, df2], ignore_index=True)
    
    # Save combined CSV
    df_combined.to_csv(output_csv, index=False)
    print(f"✅ Combined CSV saved to {output_csv}")
    print(f"   Total rows: {len(df_combined)} ({len(df1)} + {len(df2)})")
    print(f"   Total columns: {len(df_combined.columns)}")
    
    # Delete original files if requested
    if delete_originals:
        try:
            os.remove(csv1)
            print(f"🗑️  Deleted: {csv1}")
        except Exception as e:
            print(f"   ⚠️  Could not delete {csv1}: {e}")
        
        try:
            os.remove(csv2)
            print(f"🗑️  Deleted: {csv2}")
        except Exception as e:
            print(f"   ⚠️  Could not delete {csv2}: {e}")
    
    return df_combined

# %% [markdown]
# *Set up important functions*

# %%
def rescale_frame(frame, percent=50):
    '''
    Rescale a frame to a certain percentage compare to its original frame
    '''
    width = int(frame.shape[1] * percent/ 100)
    height = int(frame.shape[0] * percent/ 100)
    dim = (width, height)
    return cv2.resize(frame, dim, interpolation = cv2.INTER_AREA)
    
# def init_csv(dataset_path: str):
#     '''
#     Create a blank csv file with just columns
#     '''

#     # Ignore if file is already exist
#     if os.path.exists(dataset_path):
#         return

#     # Write all the columns to a empaty file
#     with open(dataset_path, mode="w", newline="") as f:
#         csv_writer = csv.writer(f, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL)
#         csv_writer.writerow(HEADERS)


def init_csv(csv_path):
    """Initialize CSV with proper headers for 33 landmarks (x, y, z, visibility)"""
    if os.path.exists(csv_path):
        print(f"📄 CSV already exists: {csv_path}")
        return
    
    # MediaPipe Pose landmark names (33 total)
    landmark_names = [
        'nose', 'left_eye_inner', 'left_eye', 'left_eye_outer',
        'right_eye_inner', 'right_eye', 'right_eye_outer',
        'left_ear', 'right_ear',
        'mouth_left', 'mouth_right',
        'left_shoulder', 'right_shoulder',
        'left_elbow', 'right_elbow',
        'left_wrist', 'right_wrist',
        'left_pinky', 'right_pinky',
        'left_index', 'right_index',
        'left_thumb', 'right_thumb',
        'left_hip', 'right_hip',
        'left_knee', 'right_knee',
        'left_ankle', 'right_ankle',
        'left_heel', 'right_heel',
        'left_foot_index', 'right_foot_index'
    ]
    
    # Create header: label + landmark names with x, y, z, visibility
    headers = ['label']
    for name in landmark_names:
        headers.extend([
            f'{name}_x',
            f'{name}_y',
            f'{name}_z',
            f'{name}_v'
        ])
    
    with open(csv_path, 'w', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(headers)
    
    print(f"✅ Initialized CSV with {len(headers)} columns (1 label + 33 landmarks × 4 values)")




# def export_landmark_to_csv(csv_path, results, label):
#     """Extract pose landmarks and save to CSV."""
#     if not results.pose_landmarks:
#         return
    
#     landmarks = results.pose_landmarks.landmark
#     row = [label]

#     try:
#         for lm in landmarks:
#             row += [lm.x, lm.y, lm.z, lm.visibility]

#         with open(csv_path, mode='a', newline='') as f:
#             csv.writer(f).writerow(row)
        

#     except Exception as e:
#         print(e)
#         pass


def export_landmark_to_csv(csv_path, results, label):
    """Export all 33 landmarks with x, y, z, visibility to CSV"""
    row = [label]
    
    # Extract all 33 landmarks
    for landmark in results.pose_landmarks.landmark:
        row.extend([
            landmark.x,
            landmark.y,
            landmark.z,
            landmark.visibility
        ])
    
    # Append to CSV
    with open(csv_path, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(row)
        

# def export_landmark_to_csv(dataset_path: str, results, action: str) -> None:
#     '''
#     Export Labeled Data from detected landmark to csv
#     '''
#     landmarks = results.pose_landmarks.landmark
#     keypoints = []

#     try:
#         # Extract coordinate of important landmarks
#         for lm in IMPORTANT_LMS:
#             keypoint = landmarks[mp_pose.PoseLandmark[lm].value]
#             keypoints.append([keypoint.x, keypoint.y, keypoint.z, keypoint.visibility])
        
#         keypoints = list(np.array(keypoints).flatten())

#         # Insert action as the label (first column)
#         keypoints.insert(0, action)

#         # Append new row to .csv file
#         with open(dataset_path, mode="a", newline="") as f:
#             csv_writer = csv.writer(f, delimiter=",", quotechar='"', quoting=csv.QUOTE_MINIMAL)
#             csv_writer.writerow(keypoints)
        

#     except Exception as e:
#         print(e)
#         pass


def describe_dataset(dataset_path: str):
    '''
    Describe dataset
    '''

    data = pd.read_csv(dataset_path)
    print(f"Headers: {list(data.columns.values)}")
    print(f'Number of rows: {data.shape[0]} \nNumber of columns: {data.shape[1]}\n')
    print(f"Labels: \n{data['label'].value_counts()}\n")
    print(f"Missing values: {data.isnull().values.any()}\n")
    
    # duplicate = data[data.duplicated()]
    # print(f"Duplicate Rows : {len(duplicate.sum(axis=1))}")

    print(f"Duplicate Rows : {data.duplicated().sum()}")

    return data


# def remove_duplicate_rows(dataset_path: str):
#     '''
#     Remove duplicated data from the dataset then save it to another files
#     '''
    
#     df = pd.read_csv(dataset_path)
#     df.drop_duplicates(keep="first", inplace=True)
#     df.to_csv(f"cleaned_train.csv", sep=',', encoding='utf-8', index=False)

def remove_duplicate_rows(dataset_path: str, out_path: str = None, subset: list = None, keep: str = "first"):
    """
    Remove duplicated data from the dataset then save it to another file.
    Returns the cleaned DataFrame.
    """
    import os
    if not os.path.exists(dataset_path):
        raise FileNotFoundError(f"{dataset_path} not found")

    # Explicitly specify that the first row is the header
    df = pd.read_csv(dataset_path, header=0)
    
    before = len(df)
    df_clean = df.drop_duplicates(subset=subset, keep=keep)
    removed = before - len(df_clean)

    if out_path is None:
        out_path = f"cleaned_{os.path.basename(dataset_path)}"

    # Use quoting to handle special characters in data
    df_clean.to_csv(out_path, sep=",", encoding="utf-8", index=False, quoting=1)
    print(f"Removed {removed} duplicate rows — saved to '{out_path}'")
    return df_clean

# def remove_duplicate_rows(dataset_path: str, out_path: str = None, subset: list = None, keep: str = "first"):
#     """
#     Remove duplicated data from the dataset then save it to another file.
#     Returns the cleaned DataFrame.
#     """
#     import os
#     if not os.path.exists(dataset_path):
#         raise FileNotFoundError(f"{dataset_path} not found")

#     df = pd.read_csv(dataset_path)
#     before = len(df)
#     df_clean = df.drop_duplicates(subset=subset, keep=keep)
#     removed = before - len(df_clean)

#     if out_path is None:
#         out_path = f"cleaned_{os.path.basename(dataset_path)}"

#     df_clean.to_csv(out_path, sep=",", encoding="utf-8", index=False)
#     print(f"Removed {removed} duplicate rows — saved to '{out_path}'")
#     return df_clean
    

def concat_csv_files_with_same_headers(file_paths: list, saved_path: str):
    '''
    Concat different csv files
    '''
    all_df = []
    for path in file_paths:
        df = pd.read_csv(path, index_col=None, header=0)
        all_df.append(df)
    
    results = pd.concat(all_df, axis=0, ignore_index=True)
    results.to_csv(saved_path, sep=',', encoding='utf-8', index=False)


# Extract lable from video path
def get_label_from_path_fixed(video_path):
    """Return proper label based on folder name."""
    parts = os.path.normpath(video_path).split(os.sep)
    # For example: warrior-ii_model\warrior-ii_data\Correct\Videos\example.mp4
    if len(parts) >= 3:
        label_folder = parts[-3].lower()  # "Correct"
        if label_folder == "correct":
            return "c"
        else:
            return label_folder[0].lower()
    return "u"

# %% [markdown]
# #### 2.2 Extract from video

# %%
DATASET_PATH = "train_video.csv"
VIDEO_ROOT = r"D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos"

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils


# === Initialize CSV file (if not exists) ===
init_csv(DATASET_PATH)


with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    for root, dirs, files in os.walk(VIDEO_ROOT):
        print("Processing directory:", root)
        for file in files:
            if not file.lower().endswith((".mp4", ".avi", ".mov", ".mkv")):
                continue

            video_path = os.path.join(root, file)
            label = get_label_from_path_fixed(video_path)
            print(f"🎥 Processing: {video_path} → Label: {label}")

            cap = cv2.VideoCapture(video_path)
            frame_count = 0
            frames_with_landmarks = 0

            while cap.isOpened():
                ret, image = cap.read()
                if not ret:
                    break

                frame_count += 1
                if frame_count % 4 != 0:
                    continue  # Process every 4th frame

                # Resize + Flip
                image = rescale_frame(image, 60)
                image = cv2.flip(image, 1)
                image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

                results = pose.process(image_rgb)

                if results.pose_landmarks:
                    export_landmark_to_csv(DATASET_PATH, results, label)
                    frames_with_landmarks += 1

            cap.release()
            print(f"✅ {file} → Saved {frames_with_landmarks} frames with landmarks")

cv2.destroyAllWindows()
print("🏁 Data extraction completed!")
# Out:
# ✅ Initialized CSV with 133 columns (1 label + 33 landmarks × 4 values)
# Processing directory: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample1.mp4 → Label: c
# ✅ sample1.mp4 → Saved 44 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample10.mp4 → Label: c
# ✅ sample10.mp4 → Saved 31 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample11.mp4 → Label: c
# ✅ sample11.mp4 → Saved 78 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample12.mp4 → Label: c
# ✅ sample12.mp4 → Saved 69 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample13.mp4 → Label: c
# ✅ sample13.mp4 → Saved 42 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample14.mp4 → Label: c
# ✅ sample14.mp4 → Saved 43 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample15.mp4 → Label: c
# ✅ sample15.mp4 → Saved 43 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample16.mp4 → Label: c
# ✅ sample16.mp4 → Saved 50 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample17.mp4 → Label: c
# ✅ sample17.mp4 → Saved 38 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample18.mp4 → Label: c
# ✅ sample18.mp4 → Saved 38 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample19.mp4 → Label: c
# ✅ sample19.mp4 → Saved 48 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample2.mp4 → Label: c
# ✅ sample2.mp4 → Saved 44 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample20.mp4 → Label: c
# ✅ sample20.mp4 → Saved 38 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample21.mp4 → Label: c
# ✅ sample21.mp4 → Saved 41 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample22.mp4 → Label: c
# ✅ sample22.mp4 → Saved 40 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample23.mp4 → Label: c
# ✅ sample23.mp4 → Saved 37 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample24.mp4 → Label: c
# ✅ sample24.mp4 → Saved 39 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample25.mp4 → Label: c
# ✅ sample25.mp4 → Saved 33 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample26.mp4 → Label: c
# ✅ sample26.mp4 → Saved 42 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample3.mp4 → Label: c
# ✅ sample3.mp4 → Saved 40 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample4.mp4 → Label: c
# ✅ sample4.mp4 → Saved 43 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample5.mp4 → Label: c
# ✅ sample5.mp4 → Saved 37 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample6.mp4 → Label: c
# ✅ sample6.mp4 → Saved 32 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample7.mp4 → Label: c
# ✅ sample7.mp4 → Saved 34 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample8.mp4 → Label: c
# ✅ sample8.mp4 → Saved 32 frames with landmarks
# 🎥 Processing: D:\Project_model\Mountain_Pose-Tadasana_model\warrior-ii_data\Correct\Videos\sample9.mp4 → Label: c
# ✅ sample9.mp4 → Saved 27 frames with landmarks
# 🏁 Data extraction completed!

# %%
# DATASET_PATH = "train.csv"
# VIDEO_ROOT = r"D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Videos"


# mp_pose = mp.solutions.pose
# mp_drawing = mp.solutions.drawing_utils


# # === Initialize CSV file (if not exists) ===
# init_csv(DATASET_PATH)


# # === Extract Landmarks from Videos ===
# with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#     for root, dirs, files in os.walk(VIDEO_ROOT):
#         print("Here!!")
#         for file in files:
#             if not file.lower().endswith((".mp4", ".avi", ".mov", ".mkv")):
#                 continue

#             video_path = os.path.join(root, file)
#             label = get_label_from_path_fixed(video_path)
#             print(f"🎥 Processing: {video_path} → Label: {label}")

#             cap = cv2.VideoCapture(video_path)
#             frame_count = 0
#             frames_with_landmarks = 0

#             while cap.isOpened():
#                 ret, image = cap.read()
#                 if not ret:
#                     break

#                 frame_count += 1
#                 if frame_count % 4 != 0:
#                     continue  # Skip 3 frames, process every 4th

#                 # Resize + Flip
#                 image = rescale_frame(image, 60)
#                 image = cv2.flip(image, 1)
#                 image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#                 results = pose.process(image_rgb)

#                 if results.pose_landmarks:
#                     export_landmark_to_csv(DATASET_PATH, results, label)
#                     frames_with_landmarks += 1

#             cap.release()
#             print(f"✅ {file} → Saved {frames_with_landmarks} frames with landmarks")

# cv2.destroyAllWindows()
# print("🏁 Data extraction completed from Correct\\Videos!")
# Out:
# Here!!
# 🎥 Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Videos\Virabhadrasana ii -2.mp4 → Label: c
# ✅ Virabhadrasana ii -2.mp4 → Saved 61 frames with landmarks
# 🎥 Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Videos\Virabhadrasana ii -3.mp4 → Label: c
# ✅ Virabhadrasana ii -3.mp4 → Saved 60 frames with landmarks
# 🎥 Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Videos\Virabhadrasana ii.mp4 → Label: c
# ✅ Virabhadrasana ii.mp4 → Saved 72 frames with landmarks
# 🏁 Data extraction completed from Correct\Videos!

# %%
# DATASET_PATH = "train.csv"

# # cap = cv2.VideoCapture("../data/plank/bad/plank_bad_high_4.mp4")
# cap = cv2.VideoCapture("Virabhadrasana ii -2.mp4")

# save_counts = 0

# # init_csv(DATASET_PATH)

# with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
#     while cap.isOpened():
#         ret, image = cap.read()

#         if not ret:
#             break

#         # Reduce size of a frame
#         image = rescale_frame(image, 60)
#         image = cv2.flip(image, 1)

#         # Recolor image from BGR to RGB for mediapipe
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image.flags.writeable = False

#         results = pose.process(image)

#         if not results.pose_landmarks: continue

#         # Recolor image from BGR to RGB for mediapipe
#         image.flags.writeable = True
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

#         # Draw landmarks and connections
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

#         # Display the saved count
#         cv2.putText(image, f"Saved: {save_counts}", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 0), 2, cv2.LINE_AA)

#         cv2.imshow("CV2", image)

#         # Pressed key for action
#         k = cv2.waitKey(1) & 0xFF

#         # Press C to save as correct form
#         if k == ord('c'): 
#             export_landmark_to_csv(DATASET_PATH, results, "C")
#             save_counts += 1
#         # Press L to save as low back
#         elif k == ord("l"):
#             export_landmark_to_csv(DATASET_PATH, results, "L")
#             save_counts += 1
#         # Press L to save as high back
#         elif k == ord("h"):
#             export_landmark_to_csv(DATASET_PATH, results, "H")
#             save_counts += 1

#         # Press q to stop
#         elif k == ord("q"):
#             break
#         else: continue

#     cap.release()
#     cv2.destroyAllWindows()

#     for i in range (1, 5):
#         cv2.waitKey(1)

# %%
# csv_files = [os.path.join("./", f) for f in os.listdir("./") if "csv" in f]

# concat_csv_files_with_same_headers(csv_files, "train.csv")

DATASET_PATH = "train_video.csv"

remove_duplicate_rows(DATASET_PATH)
df = describe_dataset(DATASET_PATH)
# Out:
# Removed 0 duplicate rows — saved to 'cleaned_train_video.csv'
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_eye_inner_x', 'left_eye_inner_y', 'left_eye_inner_z', 'left_eye_inner_v', 'left_eye_x', 'left_eye_y', 'left_eye_z', 'left_eye_v', 'left_eye_outer_x', 'left_eye_outer_y', 'left_eye_outer_z', 'left_eye_outer_v', 'right_eye_inner_x', 'right_eye_inner_y', 'right_eye_inner_z', 'right_eye_inner_v', 'right_eye_x', 'right_eye_y', 'right_eye_z', 'right_eye_v', 'right_eye_outer_x', 'right_eye_outer_y', 'right_eye_outer_z', 'right_eye_outer_v', 'left_ear_x', 'left_ear_y', 'left_ear_z', 'left_ear_v', 'right_ear_x', 'right_ear_y', 'right_ear_z', 'right_ear_v', 'mouth_left_x', 'mouth_left_y', 'mouth_left_z', 'mouth_left_v', 'mouth_right_x', 'mouth_right_y', 'mouth_right_z', 'mouth_right_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_elbow_x', 'left_elbow_y', 'left_elbow_z', 'left_elbow_v', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z', 'right_elbow_v', 'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'left_wrist_v', 'right_wrist_x', 'right_wrist_y', 'right_wrist_z', 'right_wrist_v', 'left_pinky_x', 'left_pinky_y', 'left_pinky_z', 'left_pinky_v', 'right_pinky_x', 'right_pinky_y', 'right_pinky_z', 'right_pinky_v', 'left_index_x', 'left_index_y', 'left_index_z', 'left_index_v', 'right_index_x', 'right_index_y', 'right_index_z', 'right_index_v', 'left_thumb_x', 'left_thumb_y', 'left_thumb_z', 'left_thumb_v', 'right_thumb_x', 'right_thumb_y', 'right_thumb_z', 'right_thumb_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v', 'left_heel_x', 'left_heel_y', 'left_heel_z', 'left_heel_v', 'right_heel_x', 'right_heel_y', 'right_heel_z', 'right_heel_v', 'left_foot_index_x', 'left_foot_index_y', 'left_foot_index_z', 'left_foot_index_v', 'right_foot_index_x', 'right_foot_index_y', 'right_foot_index_z', 'right_foot_index_v']
# Number of rows: 1083
# Number of columns: 133
#
# Labels:
# label
# c    1083
# Name: count, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
DATASET_PATH = "cleaned_train_video.csv"

filter_important_landmarks(DATASET_PATH)
# Out:
# 📊 Filtering landmarks from cleaned_train_video.csv...
# ✅ Filtered CSV saved to main_cleaned_train_video.csv
#    Original: 133 columns → Filtered: 77 columns
#    Kept 19 landmarks × 4 values + 1 label = 77 total
#    Total rows: 1083
#      label    nose_x    nose_y    nose_z    nose_v  left_ear_x  left_ear_y  \
# 0        c  0.467783  0.266316 -0.865769  0.999994    0.520526    0.255329
# 1        c  0.467692  0.266290 -0.732086  0.999994    0.520343    0.256213
# 2        c  0.467743  0.266632 -0.729495  0.999994    0.520349    0.257288
# 3        c  0.467780  0.266622 -0.716427  0.999993    0.520353    0.257752
# 4        c  0.467790  0.266579 -0.714561  0.999993    0.520383    0.257831
# ...    ...       ...       ...       ...       ...         ...         ...
# 1078     c  0.488905  0.264669 -0.337155  0.999943    0.517087    0.263481
# 1079     c  0.492916  0.264451 -0.311810  0.999946    0.523487    0.263138
# 1080     c  0.495781  0.264389 -0.314210  0.999947    0.527795    0.262867
# 1081     c  0.496435  0.264028 -0.308953  0.999948    0.527336    0.262512
# 1082     c  0.495095  0.263922 -0.361332  0.999950    0.526097    0.262232
#
#       left_ear_z  left_ear_v  right_ear_x  ...  right_ankle_z  right_ankle_v  \
# 0      -0.540408    0.999962     0.417269  ...       0.540833       0.969968
# 1      -0.417579    0.999960     0.416952  ...       0.517408       0.970171
# 2      -0.411045    0.999959     0.416842  ...       0.520709       0.969980
# 3      -0.401621    0.999957     0.416716  ...       0.523273       0.970462
# 4      -0.399913    0.999955     0.416475  ...       0.525874       0.969888
# ...          ...         ...          ...  ...            ...            ...
# 1078   -0.169983    0.999636     0.457124  ...       0.369457       0.947793
# 1079   -0.162265    0.999651     0.461888  ...       0.358182       0.947066
# 1080   -0.167532    0.999657     0.466337  ...       0.355584       0.947307
# 1081   -0.160489    0.999659     0.466797  ...       0.355740       0.945760
# 1082   -0.199877    0.999671     0.465352  ...       0.351886       0.947514
#
#       left_heel_x  left_heel_y  left_heel_z  left_heel_v  right_heel_x  \
# 0        0.533376     0.873325     0.539300     0.754716      0.482693
# 1        0.533348     0.873378     0.531468     0.759456      0.482584
# 2        0.533568     0.873387     0.541522     0.762160      0.482920
# 3        0.533684     0.873337     0.550189     0.767505      0.482871
# 4        0.533703     0.873137     0.556278     0.768089      0.483816
# ...           ...          ...          ...          ...           ...
# 1078     0.512358     0.608948     0.359075     0.679521      0.460110
# 1079     0.517224     0.610111     0.308774     0.683447      0.465073
# 1080     0.519351     0.612849     0.315202     0.689230      0.470348
# 1081     0.519976     0.612703     0.333498     0.687220      0.469012
# 1082     0.519838     0.612644     0.332102     0.693961      0.468501
#
#       right_heel_y  right_heel_z  right_heel_v
# 0         0.866989      0.573648      0.766056
# 1         0.866988      0.549189      0.766604
# 2         0.867110      0.552751      0.765316
# 3         0.867034      0.556749      0.767432
# 4         0.866411      0.560237      0.765734
# ...            ...           ...           ...
# 1078      0.614982      0.393524      0.749805
# 1079      0.615170      0.380448      0.748330
# 1080      0.615174      0.376956      0.749963
# 1081      0.614864      0.377134      0.745742
# 1082      0.614433      0.371486      0.752603
#
# [1083 rows x 77 columns]

# %%
sns.countplot(x='label', data=df, palette="Set1")
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %% [markdown]
# #### 2.3. Extract from Kaggle dataset (Photos)

# %%
DATASET_PATH = "train_photos.csv"
PHOTO_ROOT = r"D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images"

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# === Initialize CSV file ===
init_csv(DATASET_PATH)

# === Extract Landmarks from Photos ===
with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5) as pose:
    total_images = 0
    images_with_landmarks = 0

    for root, dirs, files in os.walk(PHOTO_ROOT):
        for file in files:
            if not file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff")):
                continue

            total_images += 1
            image_path = os.path.join(root, file)
            label = get_label_from_path_fixed(image_path)

            print(f"🖼️ Processing: {image_path} → Label: {label}")

            image = cv2.imread(image_path)
            if image is None:
                print(f"⚠️ Could not read image: {file}")
                continue

            image = rescale_frame(image, 60)
            image = cv2.flip(image, 1)
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

            results = pose.process(image_rgb)

            if results.pose_landmarks:
                export_landmark_to_csv(DATASET_PATH, results, label)
                images_with_landmarks += 1
            else:
                print(f"🚫 No pose detected in: {file}")

print(f"🏁 Data extraction completed from photos!")
print(f"✅ Total processed: {total_images} | Saved with landmarks: {images_with_landmarks}")
# Out:
# ✅ Initialized CSV with 133 columns (1 label + 33 landmarks × 4 values)
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File1.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File11.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File12.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File13.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File14.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File15.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File16.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File17.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File18.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File19.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File2.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File21.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File22.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File23.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File24.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File25.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File26.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File27.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File28.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File29.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File3.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File30.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File31.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File34.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File36.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File37.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File38.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File4.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File40.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File41.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File42.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File43.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File45.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File46.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File47.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File49.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File5.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File50.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File51.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File53.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File57.jpeg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File58.jpeg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File59.jpeg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File6.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File60.jpeg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File61.jpeg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File7.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File8.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\File9.png → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_10.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_100.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_101.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_102.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_103.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_104.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_105.jpg → Label: c
# 🚫 No pose detected in: Warrior_II_Pose_or_Virabhadrasana_II__image_105.jpg
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_106.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_108.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_109.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_110.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_112.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_113.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_114.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_115.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_116.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_119.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_12.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_120.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_122.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_125.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_127.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_130.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_131.jpg → Label: c
# 🚫 No pose detected in: Warrior_II_Pose_or_Virabhadrasana_II__image_131.jpg
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_135.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_136.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_140.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_141.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_142.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_143.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_144.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_147.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_149.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_150.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_151.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_157.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_158.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_159.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_161.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_164.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_167.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_169.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_17.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_171.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_173.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_174.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_177.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_178.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_18.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_180.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_183.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_19.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_190.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_192.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_193.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_195.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_199.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_20.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_205.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_209.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_21.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_213.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_215.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_22.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_221.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_223.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_224.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_228.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_23.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_231.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_234.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_24.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_241.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_242.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_243.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_25.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_252.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_259.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_260.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_262.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_265.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_27.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_271.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_272.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_273.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_274.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_28.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_280.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_283.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_286.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_287.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_289.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_29.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_290.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_293.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_299.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_3.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_301.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_303.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_306.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_307.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_31.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_315.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_316.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_32.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_321.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_323.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_324.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_325.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_326.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_33.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_331.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_332.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_333.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_334.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_336.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_338.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_339.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_34.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_340.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_341.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_342.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_343.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_346.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_347.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_348.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_35.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_350.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_351.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_352.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_353.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_354.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_356.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_358.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_360.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_37.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_38.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_39.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_40.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_41.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_42.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_43.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_44.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_45.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_46.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_49.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_5.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_50.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_51.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_54.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_55.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_56.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_58.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_61.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_62.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_65.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_66.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_67.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_68.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_69.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_70.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_71.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_74.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_75.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_76.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_77.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_78.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_79.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_8.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_81.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_82.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_83.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_88.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_91.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_92.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_93.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_94.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_96.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_98.jpg → Label: c
# 🖼️ Processing: D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images\Warrior_II_Pose_or_Virabhadrasana_II__image_99.jpg → Label: c
# 🏁 Data extraction completed from photos!
# ✅ Total processed: 229 | Saved with landmarks: 227

# %%
# DATASET_PATH = "train_photos.csv"
# PHOTO_ROOT = r"D:\Project_model\warrior-ii_model\warrior-ii_data\Correct\Images"

# mp_pose = mp.solutions.pose
# mp_drawing = mp.solutions.drawing_utils

# # === Initialize CSV file ===
# init_csv(DATASET_PATH)

# # === Extract Landmarks from Photos ===
# with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5) as pose:
#     total_images = 0
#     images_with_landmarks = 0

#     for root, dirs, files in os.walk(PHOTO_ROOT):
#         for file in files:
#             if not file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".tiff")):
#                 continue

#             total_images += 1
#             image_path = os.path.join(root, file)
#             label = get_label_from_path_fixed(image_path)

#             print(f"🖼️ Processing: {image_path} → Label: {label}")

#             image = cv2.imread(image_path)
#             if image is None:
#                 print(f"⚠️ Could not read image: {file}")
#                 continue

#             image = rescale_frame(image, 60)
#             image = cv2.flip(image, 1)
#             image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#             results = pose.process(image_rgb)

#             if results.pose_landmarks:
#                 export_landmark_to_csv(DATASET_PATH, results, label)
#                 images_with_landmarks += 1
#             else:
#                 print(f"🚫 No pose detected in: {file}")

# print(f"🏁 Data extraction completed from photos!")
# print(f"✅ Total processed: {total_images} | Saved with landmarks: {images_with_landmarks}")

# %%
DATASET_PATH = "train_photos.csv"
remove_duplicate_rows(DATASET_PATH)
df = describe_dataset(DATASET_PATH)
# Out:
# Removed 0 duplicate rows — saved to 'cleaned_train_photos.csv'
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_eye_inner_x', 'left_eye_inner_y', 'left_eye_inner_z', 'left_eye_inner_v', 'left_eye_x', 'left_eye_y', 'left_eye_z', 'left_eye_v', 'left_eye_outer_x', 'left_eye_outer_y', 'left_eye_outer_z', 'left_eye_outer_v', 'right_eye_inner_x', 'right_eye_inner_y', 'right_eye_inner_z', 'right_eye_inner_v', 'right_eye_x', 'right_eye_y', 'right_eye_z', 'right_eye_v', 'right_eye_outer_x', 'right_eye_outer_y', 'right_eye_outer_z', 'right_eye_outer_v', 'left_ear_x', 'left_ear_y', 'left_ear_z', 'left_ear_v', 'right_ear_x', 'right_ear_y', 'right_ear_z', 'right_ear_v', 'mouth_left_x', 'mouth_left_y', 'mouth_left_z', 'mouth_left_v', 'mouth_right_x', 'mouth_right_y', 'mouth_right_z', 'mouth_right_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_elbow_x', 'left_elbow_y', 'left_elbow_z', 'left_elbow_v', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z', 'right_elbow_v', 'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'left_wrist_v', 'right_wrist_x', 'right_wrist_y', 'right_wrist_z', 'right_wrist_v', 'left_pinky_x', 'left_pinky_y', 'left_pinky_z', 'left_pinky_v', 'right_pinky_x', 'right_pinky_y', 'right_pinky_z', 'right_pinky_v', 'left_index_x', 'left_index_y', 'left_index_z', 'left_index_v', 'right_index_x', 'right_index_y', 'right_index_z', 'right_index_v', 'left_thumb_x', 'left_thumb_y', 'left_thumb_z', 'left_thumb_v', 'right_thumb_x', 'right_thumb_y', 'right_thumb_z', 'right_thumb_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v', 'left_heel_x', 'left_heel_y', 'left_heel_z', 'left_heel_v', 'right_heel_x', 'right_heel_y', 'right_heel_z', 'right_heel_v', 'left_foot_index_x', 'left_foot_index_y', 'left_foot_index_z', 'left_foot_index_v', 'right_foot_index_x', 'right_foot_index_y', 'right_foot_index_z', 'right_foot_index_v']
# Number of rows: 227
# Number of columns: 133
#
# Labels:
# label
# c    227
# Name: count, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
DATASET_PATH = "cleaned_train_photos.csv"

filter_important_landmarks(DATASET_PATH)
# Out:
# 📊 Filtering landmarks from cleaned_train_photos.csv...
# ✅ Filtered CSV saved to main_cleaned_train_photos.csv
#    Original: 133 columns → Filtered: 69 columns
#    Kept 17 landmarks × 4 values + 1 label = 69 total
#    Total rows: 227
#     label    nose_x    nose_y    nose_z    nose_v  left_eye_x  left_eye_y  \
# 0       c  0.437655  0.152508 -0.402598  0.999969    0.454337    0.129483
# 1       c  0.409280  0.077575  0.001537  0.999762    0.419597    0.056919
# 2       c  0.372050  0.094486 -0.336091  0.999709    0.392808    0.075286
# 3       c  0.561121  0.122888 -0.325309  0.999983    0.553312    0.097480
# 4       c  0.419632  0.119746 -0.250630  0.999963    0.438144    0.097548
# ..    ...       ...       ...       ...       ...         ...         ...
# 222     c  0.523859  0.196117  0.041704  0.999889    0.510612    0.176065
# 223     c  0.410330  0.194136 -0.220154  0.999953    0.429313    0.174971
# 224     c  0.424106  0.146213 -0.247363  0.999939    0.438804    0.126335
# 225     c  0.477496  0.148614  0.020281  0.999769    0.465529    0.129889
# 226     c  0.543830  0.423096 -0.314525  0.999656    0.537100    0.412744
#
#      left_eye_z  left_eye_v  right_eye_x  ...  right_heel_z  right_heel_v  \
# 0     -0.405469    0.999809     0.432479  ...      0.088568      0.978687
# 1     -0.058471    0.999930     0.429959  ...      0.623533      0.965287
# 2     -0.351443    0.999138     0.380203  ...      0.040163      0.985895
# 3     -0.280922    0.999968     0.542735  ...     -0.126329      0.980602
# 4     -0.260617    0.999873     0.427426  ...     -0.011132      0.989075
# ..          ...         ...          ...  ...           ...           ...
# 222    0.032132    0.999934     0.513478  ...      0.160503      0.992562
# 223   -0.216794    0.999850     0.415162  ...     -0.044094      0.988298
# 224   -0.250451    0.999722     0.428857  ...      0.053672      0.981947
# 225   -0.040604    0.999847     0.494884  ...      0.173060      0.990349
# 226   -0.279968    0.999145     0.528666  ...      0.324196      0.814994
#
#      left_foot_index_x  left_foot_index_y  left_foot_index_z  \
# 0             0.945377           0.987349          -0.286707
# 1             0.081298           0.933119           0.316853
# 2             0.934063           0.963967          -0.308571
# 3             0.854289           0.945201          -0.188232
# 4             0.919005           0.955434          -0.032544
# ..                 ...                ...                ...
# 222           0.211338           0.898953           0.136536
# 223           0.803608           0.934920          -0.123308
# 224           0.817760           0.971051          -0.216408
# 225           0.044100           0.938926           0.191288
# 226           0.751055           0.755906           0.030277
#
#      left_foot_index_v  right_foot_index_x  right_foot_index_y  \
# 0             0.967234            0.163435            0.981361
# 1             0.982421            0.903984            0.906124
# 2             0.974629            0.018908            0.943668
# 3             0.990712           -0.008046            0.940864
# 4             0.979808            0.087362            0.964989
# ..                 ...                 ...                 ...
# 222           0.984762            0.710380            0.897877
# 223           0.985117            0.210947            0.926621
# 224           0.972980            0.129584            0.945373
# 225           0.967012            0.814445            0.902226
# 226           0.894376            0.094721            0.768231
#
#      right_foot_index_z  right_foot_index_v
# 0             -0.021600            0.939426
# 1              0.647173            0.960393
# 2             -0.095796            0.959317
# 3             -0.320645            0.996025
# 4             -0.176535            0.988433
# ..                  ...                 ...
# 222            0.165587            0.985728
# 223           -0.155718            0.985446
# 224           -0.066014            0.977821
# 225            0.151622            0.972173
# 226            0.192513            0.912939
#
# [227 rows x 69 columns]

# %%
# # FOLDER_PATH = "../data/kaggle/TRAIN/plank"
# FOLDER_PATH = "Plank_Correct"
# picture_files = [os.path.join(FOLDER_PATH, f) for f in os.listdir(FOLDER_PATH) if os.path.isfile(os.path.join(FOLDER_PATH, f))]
# print(f"Total pictures: {len(picture_files)}")

# DATASET_PATH = "./kaggle.csv"
# saved_counts = 0

# init_csv(DATASET_PATH)

# with mp_pose.Pose(min_detection_confidence=0.7, min_tracking_confidence=0.5) as pose:
#     index = 0
    
#     while True:
#         if index == len(picture_files):
#             break
        
#         file_path = picture_files[index]

#         image = cv2.imread(file_path)

#         # Flip image horizontally for more data
#         image = cv2.flip(image, 1)

#         # get dimensions of image
#         dimensions = image.shape
        
#         # height, width, number of channels in image
#         height = image.shape[0]
#         width = image.shape[1]
#         channels = image.shape[2]

#         # Reduce size of a frame
#         if width > 1000:
#             image = rescale_frame(image, 60)

#         # Recolor image from BGR to RGB for mediapipe
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#         image.flags.writeable = False

#         results = pose.process(image)

#         # Recolor image from BGR to RGB for mediapipe
#         image.flags.writeable = True
#         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

#         # Draw landmarks and connections
#         mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

#         # Display the saved count
#         cv2.putText(image, f"Saved: {saved_counts}", (20, 20), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 0), 2, cv2.LINE_AA)
        
#         cv2.imshow("CV2", image)

#         k = cv2.waitKey(1) & 0xFF

#         # Press D to skip this image (If user pressed "d", advance the index (move to the next image/frame))
#         if k == ord('d'): 
#             index += 1

#         # If user pressed "s", save current pose landmarks to DATASET_PATH with label "C" and increment saved_counts
#         elif k == ord("s"):
#             export_landmark_to_csv(DATASET_PATH, results, "C")
#             saved_counts += 1

#         # If user pressed "f", advance the index and delete the current file (file_path) from disk.
#         elif k == ord("f"):
#             index += 1
#             os.remove(file_path)

#         # If user pressed "q", exit the loop (stop processing)
#         elif k == ord("q"):
#             break

#         else:
#             continue

#         # # Press Q to close cv2 window
#         # if cv2.waitKey(1) & 0xFF == ord('d'):
#         #     index += 1

#         # # Press Q to close cv2 window
#         # if cv2.waitKey(1) & 0xFF == ord('q'):
#         #     break

#     # Close cv2 window
#     cv2.destroyAllWindows()

#     for i in range (1, 5):
#         cv2.waitKey(1)

# %% [markdown]
# ### 3. Refine Data & Data Visualization

# %%
sns.countplot(x='label', data=df, palette="Set1")
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %%
combine_and_cleanup_csvs("main_cleaned_train_video.csv", "main_cleaned_train_photos.csv")
# Out:
# 🔗 Combining CSV files...
#    📄 main_cleaned_train_video.csv
#    📄 main_cleaned_train_photos.csv
#    ✓ Loaded main_cleaned_train_video.csv: 193 rows, 69 columns
#    ✓ Loaded main_cleaned_train_photos.csv: 227 rows, 69 columns
# ✅ Combined CSV saved to train.csv
#    Total rows: 420 (193 + 227)
#    Total columns: 69
# 🗑️  Deleted: main_cleaned_train_video.csv
# 🗑️  Deleted: main_cleaned_train_photos.csv
#     label    nose_x    nose_y    nose_z    nose_v  left_eye_x  left_eye_y  \
# 0       c  0.545102  0.260763 -0.205517  0.999987    0.543061    0.242668
# 1       c  0.545697  0.260760 -0.204575  0.999986    0.543025    0.242556
# 2       c  0.546162  0.260788 -0.210042  0.999987    0.542996    0.242419
# 3       c  0.546332  0.261146 -0.203094  0.999987    0.542803    0.242452
# 4       c  0.546414  0.261260 -0.187810  0.999986    0.542535    0.242451
# ..    ...       ...       ...       ...       ...         ...         ...
# 415     c  0.523859  0.196117  0.041704  0.999889    0.510612    0.176065
# 416     c  0.410330  0.194136 -0.220154  0.999953    0.429313    0.174971
# 417     c  0.424106  0.146213 -0.247363  0.999939    0.438804    0.126335
# 418     c  0.477496  0.148614  0.020281  0.999769    0.465529    0.129889
# 419     c  0.543830  0.423096 -0.314525  0.999656    0.537100    0.412744
#
#      left_eye_z  left_eye_v  right_eye_x  ...  right_heel_z  right_heel_v  \
# 0     -0.179576    0.999966     0.536352  ...      0.007846      0.901300
# 1     -0.180319    0.999966     0.536528  ...      0.001757      0.906264
# 2     -0.190575    0.999966     0.536795  ...     -0.005847      0.911553
# 3     -0.186558    0.999966     0.536911  ...     -0.007881      0.916150
# 4     -0.170970    0.999964     0.536934  ...     -0.005755      0.920102
# ..          ...         ...          ...  ...           ...           ...
# 415    0.032132    0.999934     0.513478  ...      0.160503      0.992562
# 416   -0.216794    0.999850     0.415162  ...     -0.044094      0.988298
# 417   -0.250451    0.999722     0.428857  ...      0.053672      0.981947
# 418   -0.040604    0.999847     0.494884  ...      0.173060      0.990349
# 419   -0.279968    0.999145     0.528666  ...      0.324196      0.814994
#
#      left_foot_index_x  left_foot_index_y  left_foot_index_z  \
# 0             0.702652           0.988751          -0.156927
# 1             0.702661           0.987784          -0.159373
# 2             0.702525           0.987360          -0.157785
# 3             0.702599           0.987358          -0.157843
# 4             0.702875           0.987377          -0.153618
# ..                 ...                ...                ...
# 415           0.211338           0.898953           0.136536
# 416           0.803608           0.934920          -0.123308
# 417           0.817760           0.971051          -0.216408
# 418           0.044100           0.938926           0.191288
# 419           0.751055           0.755906           0.030277
#
#      left_foot_index_v  right_foot_index_x  right_foot_index_y  \
# 0             0.985408            0.312762            0.990084
# 1             0.986124            0.314311            0.990002
# 2             0.986840            0.314763            0.988987
# 3             0.987430            0.315108            0.988174
# 4             0.987815            0.315263            0.987887
# ..                 ...                 ...                 ...
# 415           0.984762            0.710380            0.897877
# 416           0.985117            0.210947            0.926621
# 417           0.972980            0.129584            0.945373
# 418           0.967012            0.814445            0.902226
# 419           0.894376            0.094721            0.768231
#
#      right_foot_index_z  right_foot_index_v
# 0             -0.113388            0.983387
# 1             -0.112362            0.983611
# 2             -0.114114            0.983976
# 3             -0.115528            0.984215
# 4             -0.112874            0.984232
# ..                  ...                 ...
# 415            0.165587            0.985728
# 416           -0.155718            0.985446
# 417           -0.066014            0.977821
# 418            0.151622            0.972173
# 419            0.192513            0.912939
#
# [420 rows x 69 columns]

# %% [markdown]
# ### 5. Extract data for test set

# %%
TEST_DATASET_PATH = "test.csv"

cap = cv2.VideoCapture("../data/plank/plank_test_4.mp4")
save_counts = 0

# init_csv(TEST_DATASET_PATH)

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, image = cap.read()

        if not ret:
            break

        # Reduce size of a frame
        image = rescale_frame(image, 60)
        image = cv2.flip(image, 1)

        # Recolor image from BGR to RGB for mediapipe
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False

        results = pose.process(image)

        if not results.pose_landmarks: continue

        # Recolor image from BGR to RGB for mediapipe
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw landmarks and connections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, mp_drawing.DrawingSpec(color=(244, 117, 66), thickness=2, circle_radius=4), mp_drawing.DrawingSpec(color=(245, 66, 230), thickness=2, circle_radius=2))

        # Display the saved count
        cv2.putText(image, f"Saved: {save_counts}", (50, 50), cv2.FONT_HERSHEY_COMPLEX, 2, (0, 0, 0), 2, cv2.LINE_AA)

        cv2.imshow("CV2", image)

        # Pressed key for action
        k = cv2.waitKey(1) & 0xFF

        # Press C to save as correct form
        if k == ord('c'): 
            export_landmark_to_csv(TEST_DATASET_PATH, results, "C")
            save_counts += 1
        # Press L to save as low back
        elif k == ord("l"):
            export_landmark_to_csv(TEST_DATASET_PATH, results, "L")
            save_counts += 1
        # Press L to save as high back
        elif k == ord("h"):
            export_landmark_to_csv(TEST_DATASET_PATH, results, "H")
            save_counts += 1

        # Press q to stop
        elif k == ord("q"):
            break
        else: continue

    cap.release()
    cv2.destroyAllWindows()

    for i in range (1, 5):
        cv2.waitKey(1)

# %%
test_df = describe_dataset(TEST_DATASET_PATH)
# Out:
# Headers: ['label', 'nose_x', 'nose_y', 'nose_z', 'nose_v', 'left_shoulder_x', 'left_shoulder_y', 'left_shoulder_z', 'left_shoulder_v', 'right_shoulder_x', 'right_shoulder_y', 'right_shoulder_z', 'right_shoulder_v', 'left_elbow_x', 'left_elbow_y', 'left_elbow_z', 'left_elbow_v', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z', 'right_elbow_v', 'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'left_wrist_v', 'right_wrist_x', 'right_wrist_y', 'right_wrist_z', 'right_wrist_v', 'left_hip_x', 'left_hip_y', 'left_hip_z', 'left_hip_v', 'right_hip_x', 'right_hip_y', 'right_hip_z', 'right_hip_v', 'left_knee_x', 'left_knee_y', 'left_knee_z', 'left_knee_v', 'right_knee_x', 'right_knee_y', 'right_knee_z', 'right_knee_v', 'left_ankle_x', 'left_ankle_y', 'left_ankle_z', 'left_ankle_v', 'right_ankle_x', 'right_ankle_y', 'right_ankle_z', 'right_ankle_v', 'left_heel_x', 'left_heel_y', 'left_heel_z', 'left_heel_v', 'right_heel_x', 'right_heel_y', 'right_heel_z', 'right_heel_v', 'left_foot_index_x', 'left_foot_index_y', 'left_foot_index_z', 'left_foot_index_v', 'right_foot_index_x', 'right_foot_index_y', 'right_foot_index_z', 'right_foot_index_v']
# Number of rows: 710
# Number of columns: 69
#
# Labels:
# label
# H    241
# L    235
# C    234
# Name: count, dtype: int64
#
# Missing values: False
#
# Duplicate Rows : 0

# %%
sns.countplot(y='label', data=test_df, palette="Set1")
# Out:
# <Axes: xlabel='count', ylabel='label'>
